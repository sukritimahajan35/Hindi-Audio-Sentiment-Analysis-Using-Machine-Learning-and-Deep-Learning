# %% [markdown]
# <a href="https://colab.research.google.com/github/sukritimahajan35/Hindi-Audio-Sentiment-Analysis-Using-Machine-Learning-and-Deep-Learning/blob/main/MobileNet_EfficientNet.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Import Libraries
import os
import librosa
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
from tensorflow.keras.applications import MobileNet, EfficientNetB0
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Dense, Dropout, GlobalAveragePooling2D, Concatenate
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import ReduceLROnPlateau, EarlyStopping
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Mount Google Drive
from google.colab import drive
drive.mount('/content/drive')

# Navigate to Dataset Directory
dataset_path = '/content/drive/MyDrive/Dataset'
os.chdir(dataset_path)
# Out:
# Mounted at /content/drive

# %%
# Extract File Paths and Labels
def extract_dataset(base_path):
    data = []
    emotions = ['anger', 'disgust', 'fear', 'happy', 'neutral', 'sad', 'sarcastic', 'surprise']

    # Sort actor folders numerically
    actor_folders = sorted(os.listdir(base_path), key=lambda x: int(x))

    for actor_folder in actor_folders:
        actor_path = os.path.join(base_path, actor_folder)
        if os.path.isdir(actor_path):
            # Sort session folders numerically
            session_folders = sorted(os.listdir(actor_path), key=lambda x: int(x.split('session')[-1]))

            for session_folder in session_folders:
                session_path = os.path.join(actor_path, session_folder)
                if os.path.isdir(session_path):
                    for emotion in emotions:
                        emotion_path = os.path.join(session_path, emotion)
                        if os.path.isdir(emotion_path):
                            # Sort audio files numerically
                            audio_files = sorted(os.listdir(emotion_path), key=lambda x: int(x.split('-')[-1].split('.')[0]))

                            for audio_file in audio_files:
                                data.append((os.path.join(emotion_path, audio_file), emotion))
    return pd.DataFrame(data, columns=['file_path', 'emotion'])

# Extract dataset
df = extract_dataset(dataset_path)
print(df.head())
# Out:
#                                            file_path emotion
# 0  /content/drive/MyDrive/Dataset/1/session1/ange...   anger
# 1  /content/drive/MyDrive/Dataset/1/session1/ange...   anger
# 2  /content/drive/MyDrive/Dataset/1/session1/ange...   anger
# 3  /content/drive/MyDrive/Dataset/1/session1/ange...   anger
# 4  /content/drive/MyDrive/Dataset/1/session1/ange...   anger

# %%
# Data Augmentation
def augment_audio(y, sr):
    augmented_samples = []

    # Original signal
    augmented_samples.append(y)

    # Pitch shifting
    y_pitch = librosa.effects.pitch_shift(y, sr=sr, n_steps=2)
    augmented_samples.append(y_pitch)

    # Time stretching
    y_stretch = librosa.effects.time_stretch(y, rate=0.8)
    augmented_samples.append(y_stretch)

    # Add background noise
    noise = np.random.randn(len(y)) * 0.005
    y_noisy = y + noise
    augmented_samples.append(y_noisy)

    return augmented_samples

# %%
# Feature Extraction: Convert Audio to Mel-Spectrogram
def extract_mel_spectrogram(y, sr):
    """
    Convert audio signal to Mel-spectrogram.
    """
    min_length = 22050 * 3  # Minimum length of 3 seconds at 22050 Hz sampling rate

    # Handle short signals
    if len(y) < min_length:
        y = np.pad(y, (0, min_length - len(y)), mode='constant')  # Pad short signals
    else:
        y = y[:min_length]  # Truncate long signals

    try:
        # Generate Mel-spectrogram
        mel_spectrogram = librosa.feature.melspectrogram(y=y, sr=sr, n_mels=128, fmax=8000)
        mel_spectrogram_db = librosa.power_to_db(mel_spectrogram, ref=np.max)

        # Resize to fixed dimensions (e.g., 128x128)
        mel_spectrogram_resized = librosa.util.fix_length(mel_spectrogram_db, size=128, axis=1)
        return mel_spectrogram_resized

    except Exception as e:
        print(f"Error extracting Mel-spectrogram: {e}")
        return None

# %%
# Preprocessing Pipeline with Augmentation and Feature Extraction
def preprocess_data(df):
    features = []
    labels = []
    for idx, row in df.iterrows():
        try:
            y, sr = librosa.load(row['file_path'], sr=None)

            # Step 1: Noise Reduction
            y = librosa.effects.preemphasis(y)

            # Step 2: Silence Removal
            intervals = librosa.effects.split(y, top_db=20)
            y = np.concatenate([y[start:end] for start, end in intervals])

            # Step 3: Data Augmentation
            augmented_signals = augment_audio(y, sr)

            # Step 4: Feature Extraction
            for augmented_signal in augmented_signals:
                mel_spectrogram = extract_mel_spectrogram(augmented_signal, sr)
                if mel_spectrogram is not None:  # Only append if features were successfully extracted
                    features.append(mel_spectrogram)
                    labels.append(row['emotion'])
        except Exception as e:
            print(f"Error processing file {row['file_path']}: {e}")

    features = np.array(features)
    return features, np.array(labels)


# Apply Preprocessing
X, y = preprocess_data(df)

# %%
# Encode Labels and Split Data
label_encoder = LabelEncoder()
y_encoded = label_encoder.fit_transform(y)
X_train, X_test, y_train, y_test = train_test_split(X, y_encoded, test_size=0.2, random_state=42)

# %%
# Reshape Data for CNN Input
X_train = X_train[..., np.newaxis]  # Add channel dimension for CNN
X_test = X_test[..., np.newaxis]

# %%
# Build Hybrid Model (MobileNet + EfficientNet)
def build_hybrid_model(input_shape, num_classes):
    # Load pre-trained MobileNet without top layers
    mobilenet_base = MobileNet(weights=None, include_top=False, input_shape=input_shape)
    mobilenet_output = mobilenet_base.output
    mobilenet_output = GlobalAveragePooling2D()(mobilenet_output)

    # Load pre-trained EfficientNetB0 without top layers
    efficientnet_base = EfficientNetB0(weights=None, include_top=False, input_shape=input_shape)
    efficientnet_output = efficientnet_base.output
    efficientnet_output = GlobalAveragePooling2D()(efficientnet_output)

    # Combine outputs from MobileNet and EfficientNet
    combined = Concatenate()([mobilenet_output, efficientnet_output])
    # Add custom classification layers
    x = Dropout(0.5)(combined)
    predictions = Dense(num_classes, activation='softmax')(x)

    # Create the final hybrid model
    model = Model(inputs=[mobilenet_base.input, efficientnet_base.input], outputs=predictions)
    model.compile(optimizer=Adam(learning_rate=0.001), loss='sparse_categorical_crossentropy', metrics=['accuracy'])
    return model

# Train Hybrid Model
hybrid_model = build_hybrid_model(input_shape=(128, 128, 1), num_classes=len(np.unique(y_encoded)))

callbacks = [ ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=3, verbose=1),
    EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)
]

# Prepare data for dual inputs (MobileNet and EfficientNet share the same input in this case)
X_train_dual = [X_train, X_train]
X_test_dual = [X_test, X_test]

history = hybrid_model.fit(
    X_train_dual, y_train,
    epochs=50,
    batch_size=32,
    validation_split=0.2,
    callbacks=callbacks)

# Evaluate Hybrid Model
y_pred = np.argmax(hybrid_model.predict(X_test_dual), axis=1)
print("Accuracy:", accuracy_score(y_test, y_pred))
# Out:
# Epoch 1/50
# 256/256 ━━━━━━━━━━━━━━━━━━━━ 126s 115ms/step - accuracy: 0.1670 - loss: 2.3327 - val_accuracy: 0.1230 - val_loss: 2.2841 - learning_rate: 0.0010
# Epoch 2/50
# 256/256 ━━━━━━━━━━━━━━━━━━━━ 25s 83ms/step - accuracy: 0.2723 - loss: 1.9156 - val_accuracy: 0.1230 - val_loss: 2.2879 - learning_rate: 0.0010
# Epoch 3/50
# 256/256 ━━━━━━━━━━━━━━━━━━━━ 43s 89ms/step - accuracy: 0.4021 - loss: 1.6087 - val_accuracy: 0.3740 - val_loss: 1.6753 - learning_rate: 0.0010
# Epoch 4/50
# 256/256 ━━━━━━━━━━━━━━━━━━━━ 40s 85ms/step - accuracy: 0.5103 - loss: 1.3646 - val_accuracy: 0.3784 - val_loss: 2.1192 - learning_rate: 0.0010
# Epoch 5/50
# 256/256 ━━━━━━━━━━━━━━━━━━━━ 41s 84ms/step - accuracy: 0.5845 - loss: 1.1533 - val_accuracy: 0.3823 - val_loss: 2.1897 - learning_rate: 0.0010
# Epoch 6/50
# 256/256 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step - accuracy: 0.6579 - loss: 0.9645
# Epoch 6: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 256/256 ━━━━━━━━━━━━━━━━━━━━ 23s 90ms/step - accuracy: 0.6578 - loss: 0.9647 - val_accuracy: 0.4600 - val_loss: 2.0226 - learning_rate: 0.0010
# Epoch 7/50
# 256/256 ━━━━━━━━━━━━━━━━━━━━ 41s 90ms/step - accuracy: 0.7970 - loss: 0.5982 - val_accuracy: 0.5474 - val_loss: 1.6157 - learning_rate: 5.0000e-04
# Epoch 8/50
# 256/256 ━━━━━━━━━━━━━━━━━━━━ 22s 85ms/step - accuracy: 0.8888 - loss: 0.3275 - val_accuracy: 0.5547 - val_loss: 1.7133 - learning_rate: 5.0000e-04
# Epoch 9/50
# 256/256 ━━━━━━━━━━━━━━━━━━━━ 23s 89ms/step - accuracy: 0.8962 - loss: 0.3054 - val_accuracy: 0.5737 - val_loss: 1.7070 - learning_rate: 5.0000e-04
# Epoch 10/50
# 256/256 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step - accuracy: 0.9191 - loss: 0.2394
# Epoch 10: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 256/256 ━━━━━━━━━━━━━━━━━━━━ 21s 84ms/step - accuracy: 0.9191 - loss: 0.2395 - val_accuracy: 0.5762 - val_loss: 1.8628 - learning_rate: 5.0000e-04
# Epoch 11/50
# 256/256 ━━━━━━━━━━━━━━━━━━━━ 43s 90ms/step - accuracy: 0.9526 - loss: 0.1411 - val_accuracy: 0.6533 - val_loss: 1.4769 - learning_rate: 2.5000e-04
# Epoch 12/50
# 256/256 ━━━━━━━━━━━━━━━━━━━━ 41s 90ms/step - accuracy: 0.9806 - loss: 0.0577 - val_accuracy: 0.6450 - val_loss: 1.5500 - learning_rate: 2.5000e-04
# Epoch 13/50
# 256/256 ━━━━━━━━━━━━━━━━━━━━ 40s 84ms/step - accuracy: 0.9850 - loss: 0.0493 - val_accuracy: 0.6558 - val_loss: 1.7299 - learning_rate: 2.5000e-04
# Epoch 14/50
# 256/256 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step - accuracy: 0.9819 - loss: 0.0587
# Epoch 14: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 256/256 ━━━━━━━━━━━━━━━━━━━━ 42s 89ms/step - accuracy: 0.9819 - loss: 0.0586 - val_accuracy: 0.6270 - val_loss: 1.8773 - learning_rate: 2.5000e-04
# Epoch 15/50
# 256/256 ━━━━━━━━━━━━━━━━━━━━ 40s 85ms/step - accuracy: 0.9863 - loss: 0.0468 - val_accuracy: 0.6675 - val_loss: 1.5483 - learning_rate: 1.2500e-04
# Epoch 16/50
# 256/256 ━━━━━━━━━━━━━━━━━━━━ 21s 84ms/step - accuracy: 0.9928 - loss: 0.0239 - val_accuracy: 0.6782 - val_loss: 1.5664 - learning_rate: 1.2500e-04
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 9s 21ms/step
# Accuracy: 0.660546875

# %%
# Classification Report
report = classification_report(y_test, y_pred, target_names=label_encoder.classes_)
print("\nClassification Report:")
print(report)
# Out:
# Classification Report:
#               precision    recall  f1-score   support
#
#        anger       0.74      0.75      0.74       288
#      disgust       0.67      0.59      0.63       329
#         fear       0.73      0.59      0.65       312
#        happy       0.59      0.69      0.64       344
#      neutral       0.61      0.71      0.66       317
#          sad       0.65      0.76      0.70       327
#    sarcastic       0.63      0.46      0.53       328
#     surprise       0.70      0.74      0.72       315
#
#     accuracy                           0.66      2560
#    macro avg       0.67      0.66      0.66      2560
# weighted avg       0.66      0.66      0.66      2560

# %%
# Confusion Matrix
cm = confusion_matrix(y_test, y_pred)

# Plot Confusion Matrix
plt.figure(figsize=(12, 8))
sns.set(font_scale=1.2)  # Adjust font size
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues',
            xticklabels=label_encoder.classes_,
            yticklabels=label_encoder.classes_,
            annot_kws={"size": 10}, cbar=False)

# Add Labels and Title
plt.title('Confusion Matrix', fontsize=16)
plt.xlabel('Predicted Emotion', fontsize=14)
plt.ylabel('True Emotion', fontsize=14)
plt.xticks(rotation=45, fontsize=12)
plt.yticks(rotation=0, fontsize=12)
plt.tight_layout()  # Adjust layout for better visualization
plt.show()
